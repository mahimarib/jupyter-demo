# %% [markdown]
# # FRC Stat Sheet
# Visualization of score from the Hudson Valley 2018 regional, and New York City Regional.

# %%
# %pylab inline
import pandas as pd
import seaborn as sns
from urllib.request import Request, urlopen
import json

def get_json(url):
    hdr = { 
        'X-TBA-Auth-Key' : '9l2oKd2IBt1TrlCxGhAl6pa6z06rNGcbDQrQ0EXFcMa7eCtPBdltgM5Tc69nwTOo', 
        'User-Agent': 'Mozilla /5.0 (Compatible MSIE 9.0;Windows NT 6.1;WOW64; Trident/5.0)' 
    }
    req = Request(url=url, headers=hdr)
    response = urlopen(req)
    json_text = json.loads(response.read())
    response.close()
    return json_text
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Hudson Valley 2018

# %%
json_data = get_json('https://www.thebluealliance.com/api/v3/event/2018nysu/matches')

# %%
nysu_2018 = pd.io.json.json_normalize(data=json_data, meta=[['score_breakdown', 'blue'], ['alliances', 'red']], sep='.')

# %%
nysu_2018['actual_time'] = pd.to_datetime(nysu_2018['actual_time'], unit='s')
nysu_2018.drop('alliances.blue.dq_team_keys', axis=1, inplace=True)
nysu_2018.drop('alliances.blue.surrogate_team_keys', axis=1, inplace=True)
nysu_2018.drop('alliances.red.dq_team_keys', axis=1, inplace=True)
nysu_2018.drop('alliances.red.surrogate_team_keys', axis=1, inplace=True)
nysu_2018.drop('time', axis=1, inplace=True)
nysu_2018.drop('videos', axis=1, inplace=True)
nysu_2018.drop('post_result_time', axis=1, inplace=True)
nysu_2018.drop('predicted_time', axis=1, inplace=True)
list(nysu_2018)
# Out:
# ['actual_time',
#  'alliances.blue.score',
#  'alliances.blue.team_keys',
#  'alliances.red.score',
#  'alliances.red.team_keys',
#  'comp_level',
#  'event_key',
#  'key',
#  'match_number',
#  'score_breakdown.blue.adjustPoints',
#  'score_breakdown.blue.autoOwnershipPoints',
#  'score_breakdown.blue.autoPoints',
#  'score_breakdown.blue.autoQuestRankingPoint',
#  'score_breakdown.blue.autoRobot1',
#  'score_breakdown.blue.autoRobot2',
#  'score_breakdown.blue.autoRobot3',
#  'score_breakdown.blue.autoRunPoints',
#  'score_breakdown.blue.autoScaleOwnershipSec',
#  'score_breakdown.blue.autoSwitchAtZero',
#  'score_breakdown.blue.autoSwitchOwnershipSec',
#  'score_breakdown.blue.endgamePoints',
#  'score_breakdown.blue.endgameRobot1',
#  'score_breakdown.blue.endgameRobot2',
#  'score_breakdown.blue.endgameRobot3',
#  'score_breakdown.blue.faceTheBossRankingPoint',
#  'score_breakdown.blue.foulCount',
#  'score_breakdown.blue.foulPoints',
#  'score_breakdown.blue.rp',
#  'score_breakdown.blue.tba_gameData',
#  'score_breakdown.blue.techFoulCount',
#  'score_breakdown.blue.teleopOwnershipPoints',
#  'score_breakdown.blue.teleopPoints',
#  'score_breakdown.blue.teleopScaleBoostSec',
#  'score_breakdown.blue.teleopScaleForceSec',
#  'score_breakdown.blue.teleopScaleOwnershipSec',
#  'score_breakdown.blue.teleopSwitchBoostSec',
#  'score_breakdown.blue.teleopSwitchForceSec',
#  'score_breakdown.blue.teleopSwitchOwnershipSec',
#  'score_breakdown.blue.totalPoints',
#  'score_breakdown.blue.vaultBoostPlayed',
#  'score_breakdown.blue.vaultBoostTotal',
#  'score_breakdown.blue.vaultForcePlayed',
#  'score_breakdown.blue.vaultForceTotal',
#  'score_breakdown.blue.vaultLevitatePlayed',
#  'score_breakdown.blue.vaultLevitateTotal',
#  'score_breakdown.blue.vaultPoints',
#  'score_breakdown.red.adjustPoints',
#  'score_breakdown.red.autoOwnershipPoints',
#  'score_breakdown.red.autoPoints',
#  'score_breakdown.red.autoQuestRankingPoint',
#  'score_breakdown.red.autoRobot1',
#  'score_breakdown.red.autoRobot2',
#  'score_breakdown.red.autoRobot3',
#  'score_breakdown.red.autoRunPoints',
#  'score_breakdown.red.autoScaleOwnershipSec',
#  'score_breakdown.red.autoSwitchAtZero',
#  'score_breakdown.red.autoSwitchOwnershipSec',
#  'score_breakdown.red.endgamePoints',
#  'score_breakdown.red.endgameRobot1',
#  'score_breakdown.red.endgameRobot2',
#  'score_breakdown.red.endgameRobot3',
#  'score_breakdown.red.faceTheBossRankingPoint',
#  'score_breakdown.red.foulCount',
#  'score_breakdown.red.foulPoints',
#  'score_breakdown.red.rp',
#  'score_breakdown.red.tba_gameData',
#  'score_breakdown.red.techFoulCount',
#  'score_breakdown.red.teleopOwnershipPoints',
#  'score_breakdown.red.teleopPoints',
#  'score_breakdown.red.teleopScaleBoostSec',
#  'score_breakdown.red.teleopScaleForceSec',
#  'score_breakdown.red.teleopScaleOwnershipSec',
#  'score_breakdown.red.teleopSwitchBoostSec',
#  'score_breakdown.red.teleopSwitchForceSec',
#  'score_breakdown.red.teleopSwitchOwnershipSec',
#  'score_breakdown.red.totalPoints',
#  'score_breakdown.red.vaultBoostPlayed',
#  'score_breakdown.red.vaultBoostTotal',
#  'score_breakdown.red.vaultForcePlayed',
#  'score_breakdown.red.vaultForceTotal',
#  'score_breakdown.red.vaultLevitatePlayed',
#  'score_breakdown.red.vaultLevitateTotal',
#  'score_breakdown.red.vaultPoints',
#  'set_number',
#  'winning_alliance']

# %%
nysu_2018_qm = nysu_2018[nysu_2018['comp_level'] == 'qm']
auto_scores = [nysu_2018_qm['score_breakdown.blue.autoPoints'], nysu_2018_qm['score_breakdown.red.autoPoints']]
nysu_auto_scores = pd.concat(auto_scores)

# %%
score_bins = [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500]
hist(pd.concat([nysu_2018_qm['alliances.blue.score'], nysu_2018_qm['alliances.red.score']]), 
     rwidth=.5, alpha=0.5, align='left', bins=score_bins)
xlim([-50, 500])
ylim([0, 30])
xlabel('Score')
score_labels = ['0 - 49', '50 - 99', '100 - 149', '150 - 199', '200 - 249', '300 - 349', '350 - 399', '400 - 449', 
                '450 - 499', '500 - 549']
xticks(arange(0, 500, 50), score_labels, rotation=45)
ylabel('Number of Teams')
# Out:
# Text(0,0.5,'Number of Teams')

# %%
nysu_scores = pd.concat([nysu_2018_qm['alliances.blue.score'], nysu_2018_qm['alliances.red.score']])
nysu_scores.plot('kde')
xlim([-50, 500])
ylim([0, 0.003])
xlabel('Score')
xticks(arange(0, 500, 50))
/
# Out:
# ()

# %% [markdown]
# ### Auto Scores of Alliances Qualification Matches
# Most teams only decided to cross the auton line, some decided to get ownership points

# %%
bins = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50]
nysu_auto_hist = hist(nysu_auto_scores, rwidth=.5, alpha=0.5, align='left', bins=bins)
title('Auto Scores Hudson Valley 2018')
xlim([-5, 50])
ylim([0, 40])
auto_score_label = '0 - 4, 5 - 9, 10 - 14, 15 - 19, 20 - 24, 25 - 29, 30 - 34, 35 - 39, 40 - 44, 45- 50'.split(', ')
xlabel('Auto Score')
xticks(range(0, 50, 5), auto_score_label, rotation=45)
ylabel('Number of Teams')
# Out:
# Text(0,0.5,'Number of Teams')

# %% [markdown]
# ### Distribution of Auto Scores
# The peak at 15 points shows that most alliances only crossed the auton line

# %%
nysu_auto_scores.plot(kind='kde')
xlim([-5, 50])
xticks(range(0, 50, 5))
ylim([0, 0.04])
xlabel('Score')
title('Distribution of Auto Scores')
# Out:
# Text(0.5,1,'Distribution of Auto Scores')

# %% [markdown]
# ### Scatter Plot of Overall Score vs Auto Score
# There is somewhat of a correlation of between the overall score and auto score of alliances

# %%
# nysu_auto_scatter = sns.lmplot(data=nysu_2018_qm, x='alliances.blue.score', 
#                                y='score_breakdown.blue.vaultPoints', 
#                                hue='winning_alliance', markers=['o', 'x'], fit_reg=False, legend=False)
# legend(['won', 'lost'])
pd.options.mode.chained_assignment = None
nysu_2018_qm['blue won'] = nysu_2018_qm['winning_alliance'].map(lambda x: x == 'blue')
nysu_2018_qm['red won'] = nysu_2018_qm['winning_alliance'].map(lambda x: x == 'red')

# %%
nysu_auto_scatter = sns.lmplot(data=nysu_2018_qm, x=['alliances.blue.score', 'alliances.red.score'], 
                               y=['score_breakdown.blue.vaultPoints', 'score_breakdown.red.vaultPoints'], 
                               hue=['blue won', 'red won'], markers=['o', 'x'], fit_reg=False, legend=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python36-32\lib\site-packages\seaborn\utils.py in categorical_order(values, order)
#     525             try:
# --> 526                 order = values.cat.categories
#     527             except (TypeError, AttributeError):
#
# ~\AppData\Local\Programs\Python\Python36-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#
# AttributeError: 'DataFrame' object has no attribute 'cat'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python36-32\lib\site-packages\seaborn\utils.py in categorical_order(values, order)
#     528                 try:
# --> 529                     order = values.unique()
#     530                 except AttributeError:
#
# ~\AppData\Local\Programs\Python\Python36-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#
# AttributeError: 'DataFrame' object has no attribute 'unique'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-3f2c8ccd1aec> in <module>()
#       1 nysu_auto_scatter = sns.lmplot(data=nysu_2018_qm, x=['alliances.blue.score', 'alliances.red.score'],
#       2                                y=['score_breakdown.blue.vaultPoints', 'score_breakdown.red.vaultPoints'],
# ----> 3                                hue=['blue won', 'red won'], markers=['o', 'x'], fit_reg=False, legend=False)
#
# ~\AppData\Local\Programs\Python\Python36-32\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     556                        hue_order=hue_order, height=height, aspect=aspect,
#     557                        col_wrap=col_wrap, sharex=sharex, sharey=sharey,
# --> 558                        legend_out=legend_out)
#     559
#     560     # Add the markers here as FacetGrid has figured out how many levels of the
#
# ~\AppData\Local\Programs\Python\Python36-32\lib\site-packages\seaborn\axisgrid.py in __init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws, size)
#     235             hue_names = None
#     236         else:
# --> 237             hue_names = utils.categorical_order(data[hue], hue_order)
#     238
#     239         colors = self._get_palette(data, hue, hue_order, palette)
#
# ~\AppData\Local\Programs\Python\Python36-32\lib\site-packages\seaborn\utils.py in categorical_order(values, order)
#     529                     order = values.unique()
#     530                 except AttributeError:
# --> 531                     order = pd.unique(values)
#     532                 try:
#     533                     np.asarray(values).astype(np.float)
#
# ~\AppData\Local\Programs\Python\Python36-32\lib\site-packages\pandas\core\algorithms.py in unique(values)
#     356     """
#     357
# --> 358     values = _ensure_arraylike(values)
#     359
#     360     if is_extension_array_dtype(values):
#
# ~\AppData\Local\Programs\Python\Python36-32\lib\site-packages\pandas\core\algorithms.py in _ensure_arraylike(values)
#     179             if isinstance(values, tuple):
#     180                 values = list(values)
# --> 181             values = construct_1d_object_array_from_listlike(values)
#     182         else:
#     183             values = np.asarray(values)
#
# ~\AppData\Local\Programs\Python\Python36-32\lib\site-packages\pandas\core\dtypes\cast.py in construct_1d_object_array_from_listlike(values)
#    1226     # making a 1D array that contains list-likes is a bit tricky:
#    1227     result = np.empty(len(values), dtype='object')
# -> 1228     result[:] = values
#    1229     return result
#    1230
#
# ValueError: could not broadcast input array from shape (80,2) into shape (80)

# %% [markdown]
# # New York City 2018

# %%
nyny_2018 = pd.io.json.json_normalize(data=get_json('https://www.thebluealliance.com/api/v3/event/2018nyny/matches'), 
                                      meta=[['score_breakdown', 'blue'], ['alliances', 'red']], sep='.')

# %%
nyny_2018['actual_time'] = pd.to_datetime(nyny_2018['actual_time'], unit='s')
nyny_2018.drop('alliances.blue.dq_team_keys', axis=1, inplace=True)
nyny_2018.drop('alliances.blue.surrogate_team_keys', axis=1, inplace=True)
nyny_2018.drop('alliances.red.dq_team_keys', axis=1, inplace=True)
nyny_2018.drop('alliances.red.surrogate_team_keys', axis=1, inplace=True)
nyny_2018.drop('time', axis=1, inplace=True)
nyny_2018.drop('videos', axis=1, inplace=True)
nyny_2018.drop('post_result_time', axis=1, inplace=True)
nyny_2018.drop('predicted_time', axis=1, inplace=True)

# %%
nyny_2018_qm = nyny_2018[nyny_2018['comp_level'] == 'qm']
nyny_auto_scores = pd.concat([nyny_2018_qm['score_breakdown.blue.autoPoints'], 
                              nyny_2018_qm['score_breakdown.red.autoPoints']])

# %%
hist(pd.concat([nyny_2018_qm['alliances.blue.score'], nyny_2018_qm['alliances.red.score']]), 
     rwidth=.5, alpha=0.5, align='left', bins=score_bins, color='orange')
xlim([-50, 500])
ylim([0, 30])
xlabel('Score')
xticks(arange(0, 500, 50), score_labels, rotation=45)
ylabel('Number of Teams')
# Out:
# Text(0,0.5,'Number of Teams')

# %%
nyny_scores = pd.concat([nyny_2018_qm['alliances.blue.score'], nyny_2018_qm['alliances.red.score']])
nyny_scores.plot('kde', color='orange')
xlim([-50, 500])
ylim([0, 0.003])
xlabel('Score')
xticks(arange(0, 500, 50))
/
# Out:
# ()

# %% [markdown]
# ### Auto Scores of Alliances Qualification Matches

# %%
nyny_auto_hist = hist(nyny_auto_scores, rwidth=.5, alpha=0.5, align='left', bins=bins, color='orange')
xlabel('Auto Score')
xlim([-5, 50])
ylim([0, 40])
xlabel('Auto Score')
xticks(range(0, 50, 5), auto_score_label, rotation=45)
ylabel('Number of Teams')
# Out:
# Text(0,0.5,'Number of Teams')

# %% [markdown]
# ### Distribution of Auto Scores

# %%
nyny_auto_scores.plot(kind='kde', color='orange')
xlim([-5, 50])
xticks(range(0, 50, 5))
ylim([0, 0.04])
xlabel('Score')
title('Distribution of Auto Scores')
# Out:
# Text(0.5,1,'Distribution of Auto Scores')

# %% [markdown]
# ### Scatter Plot of Overall Score vs Auto Score

# %%
nyny_2018_qm.plot(x=['alliances.blue.score', 'alliances.red.score'], 
                  y=['score_breakdown.blue.autoPoints', 'score_breakdown.red.autoPoints'], 
                  kind='scatter', color='orange')
xlabel('Overall Score')
ylabel('Auto Score')
title('Overall Score v. Auto Score')
# Out:
# Text(0.5,1,'Overall Score v. Auto Score')

# %% [markdown]
# # Hudson Valley vs New York City
# The scores are more distributed to the right in New York City

# %%
subplot(nysu_auto_scores.plot(kind='kde'), nyny_auto_scores.plot(kind='kde'))
xlim([-5, 50])
xticks(range(0, 50, 5))
ylim([0, 0.04])
xlabel('Score')
title('Distribution of Auto Scores')
legend(['Hud.', 'NYC'])

# %%
subplot(nysu_scores.plot(kind='kde'), nyny_scores.plot(kind='kde'))
xlim([-50, 500])
xticks(range(0, 500, 50))
ylim([0, 0.003])
xlabel('Score')
title('Distribution of Scores')
legend(['Hud.', 'NYC'])
